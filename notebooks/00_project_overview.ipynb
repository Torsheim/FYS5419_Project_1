# %% [markdown]
# # FYS5419 Project 1 overview
#
# Use this notebook only for exploration. Move reusable code into `src/fys5419_project1/`.

# %%
import numpy as np
import matplotlib.pyplot as plt

import fys5419_project1
print(fys5419_project1.__version__)
